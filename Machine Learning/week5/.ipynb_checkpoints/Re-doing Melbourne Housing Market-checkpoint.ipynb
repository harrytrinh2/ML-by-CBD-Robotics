# %% [markdown]
# # <center> DỰ ĐOÁN GIÁ NHÀ <center>

# %%
import numpy as np 
'''
Thư viện Numpy là một package chủ yếu cho việc tính toán khoa học trên Python. 
Vì Numpy hỗ trợ mạnh mẽ việc tính toán với matrix, vector và các các hàm đại số tuyến tính cơ bản nên nó được sử dụng nhiều 
trong việc implement các thuật toán Machine Learning.
'''
import pandas as pd
'''Pandas cung cấp nhiều đối tượng và phương thức cho các cấu trúc dữ liệu.'''
# Hiển thị full dataframe
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
'''
Đây là 2 thư viện dùng để vẽ đồ thị. Nó rất hữu ích cho bất kỳ nhà khoa học dữ liệu hoặc bất kỳ nhà phân tích dữ liệu nào.
'''
# tắt một số cảnh báo ở python
import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)
# Hiển thị plot ngay sau khi in plot
# %matplotlib inline

# %%
#Hiển thị dữ liệu 3 hàng đầu tiên
df.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford    68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council   -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council   -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council   -37.8079    144.9934
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# ...

# %%
#Xem độ lớn của data
df.shape
# Out:
# (34857, 21)

# %% [markdown]
# Vậy với data chúng ta, có tổng cộng 34857 hàng và 21 cột

# %%
df.Price.fillna(df.Price.mean(), inplace=True)
df.drop(df[df.Price > 7000000].index, inplace=True)
df.drop(df[df.Rooms == 12].index, inplace=True)
# Distance and Postcode have missing value in the same row: drop the row
df.drop(df[df.Postcode.isnull()].index, inplace=True)
df.Bedroom2.fillna(df.Bedroom2.mode()[0], inplace=True)
df.drop(df[df.Bedroom2 > 10].index, inplace=True)
df.Bathroom.fillna(df.Bathroom.mode()[0], inplace=True)
df.Car.fillna(df.Car.mode()[0], inplace=True)
df.Landsize.fillna(df.Landsize.mean(), inplace=True)
df.BuildingArea.fillna(df.BuildingArea.mean(), inplace=True)
df.YearBuilt.fillna(df.YearBuilt.mode()[0], inplace=True)
df.drop(df[df.YearBuilt <= 1850].index, inplace=True)
df.drop(df[df.YearBuilt == 2106].index, inplace=True)
df.CouncilArea.fillna("", inplace=True)
df.Lattitude.fillna(df.Lattitude.mean(), inplace=True)
df.Longtitude.fillna(df.Longtitude.mean(), inplace=True)
df.Regionname.fillna("", inplace=True)
df.Propertycount.fillna(df.Propertycount.mean(), inplace=True)

# %%
#Xem độ lớn của data
df.shape
# Out:
# (34837, 21)

# %%
#Xem độ tương quan giữa các features
plt.figure(figsize=(10,9))
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns.values,cmap="Dark2",
            yticklabels=corr.columns.values, vmax=1,
            center=0,  annot= True, square=True)

# %% [markdown]
# Ta có thể thấy cột Bedroom2 và Rooms có mối tương quan cao nhất (0,84). Chúng có thể có đa cộng tuyến nếu chúng tồn tại trong cùng một mô hình dự đoán.

# %%
#Lấy mô tả ngắn gọn về các cột kiểu object để kiểm tra xem có cần phải sử dụng one hot encode hay không.
df.describe(include=['O'])
# Out:
#            Suburb       Address   Type Method SellerG        Date  \
# count       34837         34837  34837  34837   34837       34837
# unique        350         33989      3      9     388          78
# top     Reservoir  5 Charles St      h      S  Jellis  28/10/2017
# freq          844             6  23964  19736    3358        1116
#
#                     CouncilArea             Regionname
# count                     34837                  34837
# unique                       34                      9
# top     Boroondara City Council  Southern Metropolitan
# freq                       3672                  11827
